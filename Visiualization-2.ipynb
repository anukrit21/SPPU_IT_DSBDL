# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as mat

# %%
df1 = pd.read_csv('heart.csv')
df1
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
import matplotlib.pyplot as plt
plt.hist(df1['age'],bins=10, edgecolor='k')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distrubution')
plt.show()

# %%
#plot graph for sex
df1['sex'].value_counts().plot(kind='bar')
plt.xlabel('sex (0 = female, 1 = male)')
plt.ylabel('Count')
plt.title('Gender Distribution')
plt.show()

# %%
#scatter plot of age vs cholesterol
plt.scatter(df1['age'],df1['chol'])
plt.xlabel('age')
plt.ylabel('cholesterol')
plt.title('age vs cholesterol')
plt.show()

# %%
#box-plot
plt.boxplot([df1[df1['target'] == 0]['trestbps'],
             df1[df1['target'] == 1]['trestbps']],
            labels=['No Disease', 'Disease'])
plt.xlabel('Target')
plt.ylabel('Resting Blood Pressure')
plt.title('Resting Blood Pressure by Target')

plt.tight_layout()  # Adjust the spacing between subplots
plt.show()  # Display the plots

# %%
df2 = pd.read_csv('AirQuality.csv',sep=';')
df2
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 0     10/03/2004  18.00.00    2,6       1360.0     150.0     11,9
# 1     10/03/2004  19.00.00      2       1292.0     112.0      9,4
# 2     10/03/2004  20.00.00    2,2       1402.0      88.0      9,0
# 3     10/03/2004  21.00.00    2,2       1376.0      80.0      9,2
# 4     10/03/2004  22.00.00    1,6       1272.0      51.0      6,5
# ...          ...       ...    ...          ...       ...      ...
# 9466         NaN       NaN    NaN          NaN       NaN      NaN
# 9467         NaN       NaN    NaN          NaN       NaN      NaN
# 9468         NaN       NaN    NaN          NaN       NaN      NaN
# 9469         NaN       NaN    NaN          NaN       NaN      NaN
# 9470         NaN       NaN    NaN          NaN       NaN      NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...

# %%
#scatter plot of NMHC(GT)  vs NOx(GT)
plt.scatter(df2['NMHC(GT)'],df2['NOx(GT)'])
plt.xlabel('NMHC(GT)')
plt.ylabel('NOx(GT)')
plt.title('NMHC(GT) vs NOx(GT)')
plt.show()

# %%
#scatter plot of NMHC(GT)  vs NOx(GT)
plt.scatter(df2['PT08.S5(O3)'],df2['PT08.S2(NMHC)'])
plt.xlabel('PT08.S5(O3)')
plt.ylabel('PT08.S2(NMHC)')
plt.title('PT08.S5(O3) vs PT08.S2(NMHC)')
plt.show()
